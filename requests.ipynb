# %%
# pip install requests
# pip install beautifulsoup4

# %%
import requests
url1 = 'https://assets.digitalocean.com/articles/eng_python/beautiful-soup/mockturtle.html'
url2 = 'https://dzone.com/articles/microservices-architecture-what-when-how'
page = requests.get(url2)
page.status_code
page.text
# Out:
# '<!DOCTYPE HTML>\n\n\n<html xmlns:ng="http://angularjs.org" id="ng-app" lang="en" ng-app="TH">\n\n<head ng-controller="DZHeadController">\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n    <meta name="viewport" content="width=device-width, initial-scale=1">\n\n    <meta name="description" ng-attr-content="{{ service.description }}" content="Check out what microservices are, a brief overview of when and how to use them, and advantages over monolithic structures.">\n    <meta name="keywords" ng-attr-content="{{ service.keywords }}" content="programming, software development, devops, java, agile, web, iot, database, mobile, big data, cloud,architecture &amp; design,microservices architecture,software architecture,article">\n\n    <meta property="og:description" ng-attr-content="{{ service.description }}" content="Check out what microservices are, a brief overview of when and how to use them, and advantages over monolithic structures.">\n\n    <meta ng-attr-content="{{ service.noIndex ? \'noindex\' : \'\' }}" ng-attr-name="{{ service.noIndex ? \'robots\' : \'\' }}"\n          name="" content="">\n\n    <meta property="og:site_name" ng-attr-content="{{ service.siteName }}" content="dzone.com">\n    <meta property="og:title" ng-attr-content="{{ service.title }}" content="Microservices Architecture: What, When, and How - DZone Microservices">\n    <meta property="og:url" ng-attr-content="{{ service.canonical }}" content="https://dzone.com/articles/microservices-architecture-what-when-how">\n    <meta ng-if="service.img" ng-attr-content="{{ service.img }}" property="og:image" content="https://dz2cdn3.dzone.com/storage/article-thumb/897994-thumb.jpg">\n    <meta ng-if="service.type" ng-attr-content="{{ service.type }}" property="og:type" content="article">\n\n    <meta name="twitter:site" content="@DZoneInc">\n    <meta ng-if="service.twitterImage" ng-attr-content="{{ service.twitterImage }}" name="twitter:image" content="https://dz2cdn3.dzone.com/storage/article-thumb/897994-thumb.jpg">\n    <meta name="twitter:card" content="summary_large_image">\n    <meta name="twitter:description" ng-attr-content="{{ service.description }}" content="Check out what microservices are, a brief overview of when and how to use them, and advantages over monolithic structures.">\n    <meta name="twitter:title" ng-attr-content="{{ service.title }}" content="Microservices Architecture: What, When, and How - DZone Microservices">\n\n    <meta ng-if="service.wordCount" property="article:wordcount" ng-attr-content="{{service.wordCount}}" content="2397">\n    <meta name="referrer" content="origin">\n    <meta name="google-site-verification" content="kndbhxcupfEqWmZclhCpB6vlgOs7QSmx2UHAGGnP2mA">\n\n    <link rel="dns-prefetch" href="//www.googletagservices.com">\n    <link rel="dns-prefetch" href="//www.google-analytics.com">\n    <link rel="dns-prefetch" href="//a.optnmstr.com">\n    <link rel="dns-prefetch" href="//ajax.googleapis.com">\n    <link rel="dns-prefetch" href="//csi.gstatic.com">\n\n    <link rel="image_src" ng-href="{{ service.img }}" href="https://dz2cdn3.dzone.com/storage/article-thumb/897994-thumb.jpg">\n\n    <link ng-if="service.prevPage" rel="prev" ng-href="{{ service.prevPage }}" href="">\n    <link ng-if="service.nextPage" rel="next" ng-href="{{ service.nextPage }}" href="">\n    <link rel="icon" type="image/x-icon" href="/themes/dz20/images/favicon.png">\n\n    <title ng-bind="service.title">Microservices Architecture: What, When, and How - DZone Microservices</title>\n\n    <meta name="df-verify" content="df0d76632b4543">\n\n<link rel="stylesheet" type="text/css" href="//dz2cdn3.dzone.com/storage/pub/13765907-combined.css" charset="utf-8"/><link rel="stylesheet" type="text/css" href="//dz2cdn3.dzone.com/storage/pub/13765914-combined.css" charset="utf-8"/></head>\n<body>\n\n    <noscript>\n        <iframe src="https://www.googletagmanager.com/ns.html?id=GTM-K25QL22"\n                heigh ...

# %%
from bs4 import BeautifulSoup
# print(soup.prettify())
soup.find_all('p')
soup.find_all('p')[8].get_text()
soup.find_all(class_='mobile-invisible sign-in-join')[0].get_text()
soup.find_all(id='third')
soup.find_all('p', class_='chorus')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-829d1fbe5ce0> in <module>
#       1 from bs4 import BeautifulSoup
#       2 # print(soup.prettify())
# ----> 3 soup.find_all('p')
#       4 soup.find_all('p')[8].get_text()
#       5 soup.find_all(class_='mobile-invisible sign-in-join')[0].get_text()
#
# NameError: name 'soup' is not defined
